# %% [markdown]
# <a href="https://colab.research.google.com/github/VinceManigo67/-cs1q4_practicaltest/blob/main/cs1q4_practicaltest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello!")

name = input("What is your name? ")
amountofquizzes = int(input("How many quiz scores do you want to input? "))

score = int(input("Enter score: "))
while score <= amountofquizzes:
  score = int(input("Enter score: "))
  if score < amountofquizzes:
    continue
  if score == amountofquizzes:
    break


  def total(score):
    return(score + score)
  print(score)
# Out:
# Hello!
# What is your name? 4
# How many quiz scores do you want to input? 3
# Enter score: 2
# Enter score: 1
# Enter score: 4
# 4
